# %%
import h5py as hp
import pandas as pd
import numpy as np
import time as tm
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
df=pd.read_hdf('Week_Number.h5','a')
df.head(10)
# Out:
#    artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0          1       30107       26037       47217        48594       46548
# 1         10       49064       42541       69862        76957       71259
# 2       1000        6542        6720       10402        10831       10717
# 8    1000113           4           6          16            3           9
# 9    1000131          43          44          50          118          67
# 11   1000152          16          22          25           29          48
# 23   1000317          44         303          49           62          42
# 28   1000383           3           2           8            8           9
# 30   1000419          31          12          31            5           7
# 39   1000515        1545        1522        2652         2420        3491
#
#     Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0               550               516              529              522
# ...

# %%
df['Avg_Rank']=df[['Rank_First_Week','Rank_Second_Week','Rank_Third_Week','Rank_Forth_Week']].mean(axis=1)
df.head(10)
# Out:
#    artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0          1       30107       26037       47217        48594       46548
# 1         10       49064       42541       69862        76957       71259
# 2       1000        6542        6720       10402        10831       10717
# 8    1000113           4           6          16            3           9
# 9    1000131          43          44          50          118          67
# 11   1000152          16          22          25           29          48
# 23   1000317          44         303          49           62          42
# 28   1000383           3           2           8            8           9
# 30   1000419          31          12          31            5           7
# 39   1000515        1545        1522        2652         2420        3491
#
#     Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0               550               516              529              522
# ...

# %%
df['Avg_First_Week']=df['First_Week']/4
df['Avg_Second_Week']=df['Second_Week']/7
df['Avg_Third_Week']=df['Third_Week']/7
df['Avg_Forth_Week']=df['Forth_Week']/7
df['Avg_Final_Week']=df['Final_Week']/5
df.head()
# Out:
#   artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0         1       30107       26037       47217        48594       46548
# 1        10       49064       42541       69862        76957       71259
# 2      1000        6542        6720       10402        10831       10717
# 8   1000113           4           6          16            3           9
# 9   1000131          43          44          50          118          67
#
#    Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0              550               516              529              522
# 1              387               380              399              402
# 2             1402              1485             1475             1517
# 8             4299              5248             5222             5232
# 9             4261              5133             5164             5198
#
#    Rank_Final_Week  Avg_Rank  Avg_First_Week  Avg_Second_Week  Avg_Third_Week  \
# ...

# %%
df['Total_Number']=df[['First_Week','Second_Week','Third_Week','Forth_Week']].sum(axis=1)
df.head(10)
# Out:
#    artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0          1       30107       26037       47217        48594       46548
# 1         10       49064       42541       69862        76957       71259
# 2       1000        6542        6720       10402        10831       10717
# 8    1000113           4           6          16            3           9
# 9    1000131          43          44          50          118          67
# 11   1000152          16          22          25           29          48
# 23   1000317          44         303          49           62          42
# 28   1000383           3           2           8            8           9
# 30   1000419          31          12          31            5           7
# 39   1000515        1545        1522        2652         2420        3491
#
#     Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0               550               516              529              522
# ...

# %%
df['Rank_number']=df['Total_Number'].rank(ascending=False,method='dense')
df['Rank_number']=df['Rank_number'].astype(str)
df['Rank_number']=df['Rank_number'].apply(lambda n:n[:n.index('.')])
df['Rank_number']=df['Rank_number'].astype('int64')
df.head(10)
# Out:
#    artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0          1       30107       26037       47217        48594       46548
# 1         10       49064       42541       69862        76957       71259
# 2       1000        6542        6720       10402        10831       10717
# 8    1000113           4           6          16            3           9
# 9    1000131          43          44          50          118          67
# 11   1000152          16          22          25           29          48
# 23   1000317          44         303          49           62          42
# 28   1000383           3           2           8            8           9
# 30   1000419          31          12          31            5           7
# 39   1000515        1545        1522        2652         2420        3491
#
#     Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0               550               516              529              522
# ...

# %%
df['Avg_Number']=df.Total_Number/4
df.head(10)
# Out:
#    artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0          1       30107       26037       47217        48594       46548
# 1         10       49064       42541       69862        76957       71259
# 2       1000        6542        6720       10402        10831       10717
# 8    1000113           4           6          16            3           9
# 9    1000131          43          44          50          118          67
# 11   1000152          16          22          25           29          48
# 23   1000317          44         303          49           62          42
# 28   1000383           3           2           8            8           9
# 30   1000419          31          12          31            5           7
# 39   1000515        1545        1522        2652         2420        3491
#
#     Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0               550               516              529              522
# ...

# %%
df['Max_Rank']=df[['Rank_First_Week','Rank_Second_Week','Rank_Third_Week','Rank_Forth_Week']].max(axis=1)
df['Min_Rank']=df[['Rank_First_Week','Rank_Second_Week','Rank_Third_Week','Rank_Forth_Week']].min(axis=1)
df.head(10)
# Out:
#    artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0          1       30107       26037       47217        48594       46548
# 1         10       49064       42541       69862        76957       71259
# 2       1000        6542        6720       10402        10831       10717
# 8    1000113           4           6          16            3           9
# 9    1000131          43          44          50          118          67
# 11   1000152          16          22          25           29          48
# 23   1000317          44         303          49           62          42
# 28   1000383           3           2           8            8           9
# 30   1000419          31          12          31            5           7
# 39   1000515        1545        1522        2652         2420        3491
#
#     Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0               550               516              529              522
# ...

# %%
df['Avg_mid_Rank']=df[['Max_Rank','Min_Rank']].mean(axis=1)
df.head(10)
# Out:
#    artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0          1       30107       26037       47217        48594       46548
# 1         10       49064       42541       69862        76957       71259
# 2       1000        6542        6720       10402        10831       10717
# 8    1000113           4           6          16            3           9
# 9    1000131          43          44          50          118          67
# 11   1000152          16          22          25           29          48
# 23   1000317          44         303          49           62          42
# 28   1000383           3           2           8            8           9
# 30   1000419          31          12          31            5           7
# 39   1000515        1545        1522        2652         2420        3491
#
#     Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0               550               516              529              522
# ...

# %%
df['std']=df[[ 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week','Rank_Forth_Week']].std(axis=1,ddof=1)
df['median']=df[[ 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week','Rank_Forth_Week']].median(axis=1)
df['mad']=df[[ 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week','Rank_Forth_Week']].mad(axis=1)
df['var']=df[[ 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week','Rank_Forth_Week']].var(axis=1,ddof=1)
df.head(10)
# Out:
#    artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0          1       30107       26037       47217        48594       46548
# 1         10       49064       42541       69862        76957       71259
# 2       1000        6542        6720       10402        10831       10717
# 8    1000113           4           6          16            3           9
# 9    1000131          43          44          50          118          67
# 11   1000152          16          22          25           29          48
# 23   1000317          44         303          49           62          42
# 28   1000383           3           2           8            8           9
# 30   1000419          31          12          31            5           7
# 39   1000515        1545        1522        2652         2420        3491
#
#     Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0               550               516              529              522
# ...

# %%
df['First_Rank_Gap']=df['Rank_First_Week'].apply(lambda n:1 if n<=100 else 2 if n<=1000 else 3)
df['Second_Rank_Gap']=df['Rank_Second_Week'].apply(lambda n:1 if n<=100 else 2 if n<=1000 else 3)
df['Third_Rank_Gap']=df['Rank_Third_Week'].apply(lambda n:1 if n<=100 else 2 if n<=1000 else 3)
df['Forth_Rank_Gap']=df['Rank_Forth_Week'].apply(lambda n:1 if n<=100 else 2 if n<=1000 else 3)
df['Final_Rank_Gap']=df['Rank_Final_Week'].apply(lambda n:1 if n<=100 else 2 if n<=1000 else 3)
df.head()
# Out:
#   artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0         1       30107       26037       47217        48594       46548
# 1        10       49064       42541       69862        76957       71259
# 2      1000        6542        6720       10402        10831       10717
# 8   1000113           4           6          16            3           9
# 9   1000131          43          44          50          118          67
#
#    Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  \
# 0              550               516              529              522
# 1              387               380              399              402
# 2             1402              1485             1475             1517
# 8             4299              5248             5222             5232
# 9             4261              5133             5164             5198
#
#         ...        Avg_mid_Rank         std  median      mad            var  \
# ...

# %%
df['First']=abs(df['First_Week']-df['Second_Week'])
df['Second']=abs(df['Second_Week']-df['Third_Week'])
df['Third']=abs(df['Third_Week']-df['Forth_Week'])
df.head()
# Out:
#   artist_id  Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# 0         1       30107       26037       47217        48594       46548
# 1        10       49064       42541       69862        76957       71259
# 2      1000        6542        6720       10402        10831       10717
# 8   1000113           4           6          16            3           9
# 9   1000131          43          44          50          118          67
#
#    Rank_First_Week  Rank_Second_Week  Rank_Third_Week  Rank_Forth_Week  ...    \
# 0              550               516              529              522  ...
# 1              387               380              399              402  ...
# 2             1402              1485             1475             1517  ...
# 8             4299              5248             5222             5232  ...
# 9             4261              5133             5164             5198  ...
#
# ...

# %%
df.columns
# Out:
# Index(['artist_id', 'Final_Week', 'First_Week', 'Forth_Week', 'Second_Week',
#        'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
#        'Rank_Forth_Week', 'Rank_Final_Week', 'Avg_Rank', 'Avg_First_Week',
#        'Avg_Second_Week', 'Avg_Third_Week', 'Avg_Forth_Week', 'Avg_Final_Week',
#        'Total_Number', 'Rank_number', 'Avg_Number', 'Avg_Number_Rank',
#        'Max_Rank', 'Min_Rank', 'Avg_mid_Rank', 'std', 'median', 'mad', 'var',
#        'First_Rank_Gap', 'Second_Rank_Gap', 'Third_Rank_Gap', 'Forth_Rank_Gap',
#        'Final_Rank_Gap', 'First', 'Second', 'Third'],
#       dtype='object')

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel

# %%
clf = ExtraTreesClassifier()
clf = clf.fit(df.loc[:,['First_Week', 'Forth_Week', 'Second_Week',
       'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week', 'Avg_Rank', 'Total_Number',
       'Rank_number', 'Avg_Number', 'Avg_Number_Rank', 'Max_Rank', 'Min_Rank',
       'Avg_mid_Rank', 'std', 'median', 'mad', 'var','Avg_First_Week',
       'Avg_Second_Week', 'Avg_Third_Week', 'Avg_Forth_Week','First', 'Second', 'Third']], df.loc[:,['Rank_Final_Week']])
clf.feature_importances_
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# array([0.03268213, 0.03663806, 0.03532064, 0.03823159, 0.03221139,
#        0.0363132 , 0.03873848, 0.03664897, 0.03719952, 0.03635088,
#        0.0368035 , 0.03594855, 0.03723276, 0.03728184, 0.03242733,
#        0.03772806, 0.04040329, 0.04046554, 0.03691309, 0.03951664,
#        0.03264654, 0.03675945, 0.03813317, 0.03749271, 0.03851527,
#        0.04054478, 0.04085263])

# %%
model = SelectFromModel(clf, prefit=True)
X_new = model.transform(df.loc[:,['First_Week', 'Forth_Week', 'Second_Week',
       'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week', 'Avg_Rank', 'Total_Number',
       'Rank_number', 'Avg_Number', 'Avg_Number_Rank', 'Max_Rank', 'Min_Rank',
       'Avg_mid_Rank', 'std', 'median', 'mad', 'var','Avg_First_Week',
       'Avg_Second_Week', 'Avg_Third_Week', 'Avg_Forth_Week','First', 'Second', 'Third']])
X_new.shape
# Out:
# (49090, 14)

# %%
X_new
# Out:
# array([[4.65480e+04, 5.29000e+02, 5.29250e+02, ..., 2.25570e+04,
#         2.04600e+03, 6.69000e+02],
#        [7.12590e+04, 3.99000e+02, 3.92000e+02, ..., 3.44160e+04,
#         5.69800e+03, 1.39700e+03],
#        [1.07170e+04, 1.47500e+03, 1.46975e+03, ..., 4.11100e+03,
#         1.14000e+02, 3.15000e+02],
#        ...,
#        [1.10000e+01, 5.22000e+03, 5.00250e+03, ..., 0.00000e+00,
#         8.00000e+00, 3.00000e+00],
#        [1.40000e+01, 5.21700e+03, 4.99650e+03, ..., 2.00000e+00,
#         2.00000e+00, 1.00000e+00],
#        [3.00000e+00, 5.22800e+03, 5.00625e+03, ..., 1.00000e+00,
#         2.00000e+00, 1.00000e+00]])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.feature_selection import RFE
clf = RandomForestRegressor(n_estimators=50, max_depth=14)
selector = RFE(clf, 1, step=1)
selector = selector.fit(df.loc[:,['First_Week', 'Forth_Week', 'Second_Week',
       'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week', 'Avg_Rank', 'Total_Number',
       'Rank_number', 'Avg_Number', 'Avg_Number_Rank', 'Max_Rank', 'Min_Rank',
       'Avg_mid_Rank', 'std', 'median', 'mad', 'var','Avg_First_Week',
       'Avg_Second_Week', 'Avg_Third_Week', 'Avg_Forth_Week','First', 'Second', 'Third']],df.loc[:,['Rank_Final_Week']])
print (selector.ranking_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [26  8 27 25 21 19 22  4 11  1  5  7  2  9 20  3 23 10 12 18 14 24 13  6
#  16 17 15]

# %%
df.corr()

# %%
df.corr('pearson')

# %%
df.corr('kendall')

# %%
df.corr('spearman')
# Out:
#                   Final_Week  First_Week  Forth_Week  Second_Week  Third_Week  \
# Final_Week          1.000000    0.852208    0.902986     0.876704    0.887126
# First_Week          0.852208    1.000000    0.868654     0.898949    0.879450
# Forth_Week          0.902986    0.868654    1.000000     0.895442    0.914354
# Second_Week         0.876704    0.898949    0.895442     1.000000    0.913339
# Third_Week          0.887126    0.879450    0.914354     0.913339    1.000000
# Rank_First_Week    -0.852208   -1.000000   -0.868654    -0.898949   -0.879450
# Rank_Second_Week   -0.876704   -0.898949   -0.895442    -1.000000   -0.913339
# Rank_Third_Week    -0.887126   -0.879450   -0.914354    -0.913339   -1.000000
# Rank_Forth_Week    -0.902986   -0.868654   -1.000000    -0.895442   -0.914354
# Rank_Final_Week    -1.000000   -0.852208   -0.902986    -0.876704   -0.887126
# Avg_Rank           -0.910470   -0.927283   -0.959283    -0.958981   -0.963081
# ...

# %%
df.cov()

# %%
import pandas as pd
from sklearn import tree

from sklearn.cross_validation import train_test_split
from sklearn import metrics

from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
X = df.loc[:,['Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week',
       'Rank_number',  'Avg_Number_Rank', 'Max_Rank', 'Min_Rank']].values
'''
X = df.loc[:,[ 'First_Week', 'Forth_Week', 'Second_Week',
       'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week', 'Total_Number',
       'Rank_number', 'Avg_Number', 'Avg_Number_Rank', 'Max_Rank', 'Min_Rank']].values
'''
Y = df.loc[:,'Rank_Final_Week'].astype(str).values
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
'''
X = df.loc[:1000,[ 'First_Week', 'Forth_Week', 'Second_Week',
       'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week', 'Avg_Rank', 'Total_Number',
       'Rank_number', 'Avg_Number', 'Avg_Number_Rank', 'Max_Rank', 'Min_Rank']]
Y = df.loc[:,'Rank_Final_Week']
x = df.loc[1001:,[ 'First_Week', 'Forth_Week', 'Second_Week',
       'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week', 'Avg_Rank', 'Total_Number',
       'Rank_number', 'Avg_Number', 'Avg_Number_Rank', 'Max_Rank', 'Min_Rank']]
y = df.loc[:,'Rank_Final_Week']
'''
X=X_train
Y=Y_train
x=X_validation
y=Y_validation
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=.5)

clrTree = tree.DecisionTreeClassifier()
clrTree = clrTree.fit(X, Y)
outTree = clrTree.predict(x)

clrKN = KNeighborsClassifier()
clrKN = clrKN.fit(X, Y)
outKN = clrKN.predict(x)

# Prediction accuracy
print("Accuracy for Decision Tree Classifier: " + str(accuracy_score(y, outTree)*100)+"%")
print("Accuracy for KNeighbors Classifier: " + str(accuracy_score(y, outKN)*100)+"%")
# Out:
# Accuracy for Decision Tree Classifier: 5.938072927276431%
# Accuracy for KNeighbors Classifier: 5.286209003870442%

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
regressor = regressor.fit(X, Y)
out=regressor.predict(x)
print(regressor.score(X,Y))
print(regressor.score(x,y))
# Out:
# 0.9209745084749472
# 0.9343974226735564

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
y_pred = gnb.fit(X, Y).predict(x)


# Calculate Accuracy Rate by using accuracy_score()
print("Accuracy Rate, which is calculated by accuracy_score() is: %f" % accuracy_score(y, y_pred))
# Out:
# Accuracy Rate, which is calculated by accuracy_score() is: 0.996130

# %%
import numpy as np
import pandas as pd
from sklearn import cross_validation, ensemble, preprocessing, metrics
# 建立 random forest 模型
forest = ensemble.RandomForestClassifier(n_estimators = 10)
forest_fit = forest.fit(X, Y)

# 預測
test_y_predicted = forest.predict(x)

# 績效
accuracy = metrics.accuracy_score(y, test_y_predicted)
print(accuracy)

# %%
df.values[:,1:]

# %%
from pandas.tools.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
array = df.values
X = df.loc[:,[ 'First_Week', 'Forth_Week', 'Second_Week',
       'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week', 'Rank_Final_Week', 'Avg_Rank', 'Total_Number',
       'Rank_number', 'Avg_Number', 'Avg_Number_Rank', 'Max_Rank', 'Min_Rank']].values
Y = df.loc[:,'Rank_Final_Week'].values
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)

# %%
outTree

# %%
Y_validation

# %%
for u in print(Y_validation,outTree).values:
    print(u)

# %%
clrTree = tree.DecisionTreeClassifier()
clrTree = clrTree.fit(X_train, Y_train)
outTree = clrTree.predict(X_validation)
print("Accuracy for Decision Tree Classifier: " + str(accuracy_score(Y_validation, outTree)*100)+"%")

# %%
print(classification_report(Y_validation,outTree))

# %%
outTree

# %%
pd.DataFrame([outTree,Y_validation])

# %%
outTree = np.array(outTree)
Y_validation = np.array(y)


dataset = pd.DataFrame({'outTree': outTree, 'Y_validation': list(Y_validation)}, columns=['outTree', 'Y_validation'])

# %%
dataset

# %%
dataset['std']=dataset[['outTree','Y_validation']].std(axis=1,ddof=1)
dataset
# Out:
#       outTree  Y_validation          std
# 0        4453          4422    21.920310
# 1        4503          4455    33.941125
# 2        4398          4460    43.840620
# 3        4485          4496     7.778175
# 4        4507          4496     7.778175
# 5        3667          3710    30.405592
# 6        4465          4463     1.414214
# 7        3054          3468   292.742207
# 8        4505          4508     2.121320
# 9        4215          4246    21.920310
# 10       4507          4462    31.819805
# 11       3313          4208   632.860569
# 12       4497          4483     9.899495
# 13       4502          4501     0.707107
# 14       4507          4504     2.121320
# 15       4188          4288    70.710678
# 16       4469          4443    18.384776
# 17       4502          4501     0.707107
# 18       4450          4473    16.263456
# 19       4505          4508     2.121320
# 20       2351          2453    72.124892
# 21       4413          4470    40.305087
# ...

# %%
dataset[dataset['outTree']!=dataset['Y_validation']]
# Out:
#       outTree  Y_validation          std
# 0        4453          4422    21.920310
# 1        4503          4455    33.941125
# 2        4398          4460    43.840620
# 3        4485          4496     7.778175
# 4        4507          4496     7.778175
# 5        3667          3710    30.405592
# 6        4465          4463     1.414214
# 7        3054          3468   292.742207
# 8        4505          4508     2.121320
# 9        4215          4246    21.920310
# 10       4507          4462    31.819805
# 11       3313          4208   632.860569
# 12       4497          4483     9.899495
# 13       4502          4501     0.707107
# 14       4507          4504     2.121320
# 15       4188          4288    70.710678
# 16       4469          4443    18.384776
# 17       4502          4501     0.707107
# 18       4450          4473    16.263456
# 19       4505          4508     2.121320
# 20       2351          2453    72.124892
# 21       4413          4470    40.305087
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

X = df.loc[:,[  'First_Week', 'Forth_Week', 'Second_Week',
       'Third_Week', 'Rank_First_Week', 'Rank_Second_Week', 'Rank_Third_Week',
       'Rank_Forth_Week', 'Avg_Rank', 'Max_Rank', 'Min_Rank']].values
Y = df.loc[:,'Rank_Final_Week'].values

#X = df.loc[:,[ 'Total_Number']].values
#Y = df.loc[:,'Rank_number'].values
validation_size = 0.20
seed = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)


X=X_train
Y=Y_train
x=X_validation
y=Y_validation
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=.5)

clrTree = tree.DecisionTreeClassifier()
clrTree = clrTree.fit(X, Y)
outTree = clrTree.predict(x)

clrKN = KNeighborsClassifier()
clrKN = clrKN.fit(X, Y)
outKN = clrKN.predict(x)

# Prediction accuracy
print("Accuracy for Decision Tree Classifier: " + str(accuracy_score(y, outTree)*100)+"%")
print("Accuracy for KNeighbors Classifier: " + str(accuracy_score(y, outKN)*100)+"%")

# %%
outKN

# %%
y

# %%
df.sort_values('mad',ascending=True)

# %%
df.sort_values('Rank_Final_Week',ascending=True).iloc[:,5:].head(10)
# Out:
#         Third_Week  Rank_First_Week  Rank_Second_Week  Rank_Third_Week  \
# 93501      6227453                1                 1                1
# 141434     4696105                2                 2                2
# 158458     3262190                3                 3                4
# 114549     2567695                6                 5                6
# 95614      3101041               25                26                5
# 106501     3337862                8                 6                3
# 90158      2397783                4                 4                7
# 16585      2226310               12                15                9
# 65173      2337695               21                 7                8
# 53172      2061236                5                 8               10
#
#         Rank_Forth_Week  Rank_Final_Week  Avg_Rank  Avg_First_Week  \
# 93501                 1                1      1.00       960011.00
# ...

# %%
df.sort_values('Avg_Rank',ascending=True).iloc[:,5:].head(10)
# Out:
#         Third_Week  Rank_First_Week  Rank_Second_Week  Rank_Third_Week  \
# 93501      6227453                1                 1                1
# 141434     4696105                2                 2                2
# 158458     3262190                3                 3                4
# 90158      2397783                4                 4                7
# 114549     2567695                6                 5                6
# 106501     3337862                8                 6                3
# 53172      2061236                5                 8               10
# 98090      2052226               10                 9               11
# 65173      2337695               21                 7                8
# 48935      1803376                9                10               12
#
#         Rank_Forth_Week  Rank_Final_Week  Avg_Rank  Avg_First_Week  \
# 93501                 1                1      1.00       960011.00
# ...
